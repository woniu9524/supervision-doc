# %% [markdown]
# # 下载 Supervision 资源
#
# ---
#
# [![Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/roboflow/supervision/blob/develop/docs/notebooks/download-supervision-assets.ipynb)
#
# 当你在试验 Supervision 包中各种有趣且实用的功能时，拥有一些图像或视频数据素材来进行实验非常重要。幸运的是，Supervision 自带了 [Assets](https://supervision.roboflow.com/latest/assets/)！Assets 是一个视频集合，你可以利用这些视频来开始尝试 Supervision 提供的各种功能。让我们来看看如何使用这个资源。
#
# ## 安装依赖

# %%
pip install -q "supervision"

# %% [markdown]
# ## 下载视频
#
# 然后，我们就可以直接从 Python 脚本中下载和使用视频资源了！请注意，下面我们正使用 `download_assets` 方法将 `VideoAssets.SUBWAY` 视频下载到本地目录。此方法会返回文件路径，我们之后就可以使用此路径进行进一步的实验。在这里，你将在本地目录中看到一个视频资源可供实验。

# %%
from supervision.assets import download_assets, VideoAssets

# Download the a video of the subway.
path_to_video = download_assets(VideoAssets.SUBWAY)

# %% [markdown]
# 至此，我们拥有了一个高质量的视频素材，可用于演示。让我们来看看我们下载了什么。请注意，下面的视频预览仅在 cookbook 的 Web 版本中有效，而在 Google Colab 中无效。

# %% [markdown]
# <div style="display: flex; justify-content: center;">
#     <video controls width="320" height="240">
#         <source
#             src="https://media.roboflow.com/supervision/video-examples/subway.mp4"
#             type="video/mp4"
#         >
#     </video>
# </div>

# %% [markdown]
# 现在我们已经配备了来自 Supervision 的视频素材，可以进行一些实验了！有关可用素材的更多信息，请访问 [Supervision API Reference](https://supervision.roboflow.com/latest/assets)。祝你构建愉快！
